# %% [markdown]
# <a href="https://colab.research.google.com/github/patilhumesh88-spec/code/blob/main/data_preprocesssing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open ("example_test.txt",'w') as file:
  file.write("This is sample file for text.\n")
  file.write("This is second line for text.\n")
  file.write("This is third line for text.\n")
print("File created sucessfully")
# Out:
# File created sucessfully

# %%
with open ("exp_tst.txt",'w') as file:
  for i in range (1,10):
    file.write( f"this line is {i}.\n" )
print("File created sucessfully")
# Out:
# File created sucessfully

# %%
with open ("exp_tst.txt",'r') as file:
    data=file.read()
    print(data)
# Out:
# this line is 1.
# this line is 2.
# this line is 3.
# this line is 4.
# this line is 5.
# this line is 6.
# this line is 7.
# this line is 8.
# this line is 9.
