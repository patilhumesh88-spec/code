# %% [markdown]
# <a href="https://colab.research.google.com/github/patilhumesh88-spec/code/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
from google.colab import files

url = "https://archive-api.open-meteo.com/v1/archive"
params = {
    "latitude": 28.6139,
    "longitude": 77.2090,
    "start_date": "2019-01-01",
    "end_date": "2024-12-31",
    "hourly": "temperature_2m,relative_humidity_2m,precipitation,cloud_cover,wind_speed_10m",
    "timezone": "Asia/Kolkata"
}

# Fetch data
response = requests.get(url, params=params)
data = response.json()

# Convert to DataFrame
df = pd.DataFrame(data['hourly'])

# Save to CSV
csv_filename = 'weather_data_FIXED.csv'
df.to_csv(csv_filename, index=False)

# Print info
print(f"Total rows: {len(df)}")
print(df.head())

# Download CSV in Colab
files.download(csv_filename)
# Out:
# Total rows: 52608
#                time  temperature_2m  relative_humidity_2m  precipitation  \
# 0  2019-01-01T00:00             8.8                    84            0.0
# 1  2019-01-01T01:00             8.1                    86            0.0
# 2  2019-01-01T02:00             7.6                    87            0.0
# 3  2019-01-01T03:00             7.2                    88            0.0
# 4  2019-01-01T04:00             7.1                    88            0.0
#
#    cloud_cover  wind_speed_10m
# 0            0             8.8
# 1            0             8.9
# 2            0             8.4
# 3            0             7.2
# 4            0             6.1
